# %%
import pandas as pd
import json

# %%
df = pd.read_csv("./liber_777.csv")

# %%
df = df.transpose()

# %%
df.tail()
# Out:
#                                                                                                    0   \
# 44 - Mineral Drugs                                                                             Carbon
# 45 - Magical Powers                                 The Supreme Attainment [[Vision of No Differen...
# 46- System of Taoism                                          The Tao or Great Extreme of the Yi King
# 48 - Figures related to Pure Number                                                               ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                                         The Circle
#
#                                                                          1   \
# 44 - Mineral Drugs                                                Aur. Pot.
# 45 - Magical Powers                                          Union with God
# 46- System of Taoism                                Shang Ti (also the Tao)
# 48 - Figures related to Pure Number                                     ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                The Point
#
#                                                                                                    2   \
# 44 - Mineral Drugs                                                                         Phosphorus
# 45 - Magical Powers                                 The Vision of God face to face [[Vision of Ant...
# 46- System of Taoism                                                               The Yang and Khien
# 48 - Figures related to Pure Number                                                         The Cross
# 49 - Lineal Figures of the Planets, &c., and Ge...                           The Line, also the Cross
#
#                                                                                                    3   \
# 44 - Mineral Drugs                                                                             Silver
# 45 - Magical Powers                                         The Vision of Sorrow [[Vision of Wonder]]
# 46- System of Taoism                                                    Kwan-se-on, The Yin and Khwan
# 48 - Figures related to Pure Number                                                      The Triangle
# 49 - Lineal Figures of the Planets, &c., and Ge...  The Plane, also the Diamond, Oval, Circle, and...
#
#                                                                                4   \
# 44 - Mineral Drugs                                                            ...
# 45 - Magical Powers                                            The Vision of Love
# 46- System of Taoism                                                          ...
# 48 - Figures related to Pure Number                 Tetrahedron or Pyramid, Cross
# 49 - Lineal Figures of the Planets, &c., and Ge...               The Solid Figure
#
#                                                                      5   \
# 44 - Mineral Drugs                                        Iron, Sulphur
# 45 - Magical Powers                                 The Vision of Power
# 46- System of Taoism                                                ...
# 48 - Figures related to Pure Number                            The Rose
# 49 - Lineal Figures of the Planets, &c., and Ge...        The Tesseract
#
#                                                                                                    6   \
# 44 - Mineral Drugs                                                                                ...
# 45 - Magical Powers                                 The Vision of the Harmony of Things (also the ...
# 46- System of Taoism                                                                               Li
# 48 - Figures related to Pure Number                            Calvary Cross, Truncated Pyramid, Cube
# 49 - Lineal Figures of the Planets, &c., and Ge...                                                ...
#
#                                                                                  7   \
# 44 - Mineral Drugs                                                          Arsenic
# 45 - Magical Powers                                 The Vision of Beauty Triumphant
# 46- System of Taoism                                                            ...
# 48 - Figures related to Pure Number                       A Rose (7x7), Candlestick
# 49 - Lineal Figures of the Planets, &c., and Ge...                              ...
#
#                                                                                    8   \
# 44 - Mineral Drugs                                                            Mercury
# 45 - Magical Powers                                 The Vision of Splendour [Ezekiel]
# 46- System of Taoism                                                              ...
# 48 - Figures related to Pure Number                                               ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                                ...
#
#                                                                                              9   \
# 44 - Mineral Drugs                                                                         Lead
# 45 - Magical Powers                                 The Vision of the Machinery of the Universe
# 46- System of Taoism                                                                        ...
# 48 - Figures related to Pure Number                                                         ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                                          ...
#
#                                                     ...  \
# 44 - Mineral Drugs                                  ...
# 45 - Magical Powers                                 ...
# 46- System of Taoism                                ...
# 48 - Figures related to Pure Number                 ...
# 49 - Lineal Figures of the Planets, &c., and Ge...  ...
#
#                                                                                                 25  \
# 44 - Mineral Drugs                                                                             ...
# 45 - Magical Powers                                 Transmutations [[Vision of Universal Peacock]]
# 46- System of Taoism                                                                           ...
# 48 - Figures related to Pure Number                                                 The Rose (5x5)
# 49 - Lineal Figures of the Planets, &c., and Ge...                                     Acquisitio*
#
#                                                                                               26  \
# 44 - Mineral Drugs                                                                           ...
# 45 - Magical Powers                                 The Witches' Sabbath so-called, the Evil Eye
# 46- System of Taoism                                                                         ...
# 48 - Figures related to Pure Number                                   Calvary Cross of 10, Solid
# 49 - Lineal Figures of the Planets, &c., and Ge...                                       Carcer*
#
#                                                                               27  \
# 44 - Mineral Drugs                                                           ...
# 45 - Magical Powers                                 Works of Wrath and Vengeance
# 46- System of Taoism                                                         Kan
# 48 - Figures related to Pure Number                                          ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                     Pentagram
#
#                                                             28  \
# 44 - Mineral Drugs                                         ...
# 45 - Magical Powers                                  Astrology
# 46- System of Taoism                                       ...
# 48 - Figures related to Pure Number                        ...
# 49 - Lineal Figures of the Planets, &c., and Ge...  Tristitia*
#
#                                                                                  29  \
# 44 - Mineral Drugs                                                              ...
# 45 - Magical Powers                                 Bewitchments, Casting Illusions
# 46- System of Taoism                                                            ...
# 48 - Figures related to Pure Number                                             ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                        Laetitia*
#
#                                                                                              30  \
# 44 - Mineral Drugs                                                                          ...
# 45 - Magical Powers                                 The Red Tincture, Power of Acquiring Wealth
# 46- System of Taoism                                                               Li and Khien
# 48 - Figures related to Pure Number                                                         ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                                     Hexagram
#
#                                                                         31  \
# 44 - Mineral Drugs                                                Nitrates
# 45 - Magical Powers                                   Evocation, Pyromancy
# 46- System of Taoism                                                   Kan
# 48 - Figures related to Pure Number                                    ...
# 49 - Lineal Figures of the Planets, &c., and Ge...  Those of 🜂y Triplicity
#
#                                                                                 32  \
# 44 - Mineral Drugs                                                            Lead
# 45 - Magical Powers                                 Works of Malediction and Death
# 46- System of Taoism                                                          Khan
# 48 - Figures related to Pure Number                                            ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                        Triangle
#
#                                                                                                    33  \
# 44 - Mineral Drugs                                                                            Bismuth
# 45 - Magical Powers                                 Alchemy, Geomancy, Making of Pantacles [[Trave...
# 46- System of Taoism                                                                              Kan
# 48 - Figures related to Pure Number                                                               ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                             Those of 🜃y Triplicity
#
#                                                                                                    34
# 44 - Mineral Drugs                                                                             Carbon
# 45 - Magical Powers                                 Invisibility, Transformations, Vision of the G...
# 46- System of Taoism                                                                              ...
# 48 - Figures related to Pure Number                                                               ...
# 49 - Lineal Figures of the Planets, &c., and Ge...                                                ...
#
# [5 rows x 35 columns]

# %%
df = df.reset_index()

# %%
df = df.iloc[1:]

# %%
json_string = df.to_json(orient='records', force_ascii=False)
o = json.loads(json_string)

# %%
json_data = json.dumps(o, ensure_ascii=False).encode('utf-8').decode('unicode_escape')

# Specify the JavaScript file path
js_file_path = '../src/liber_777.js'

import json
with open(js_file_path, 'w', encoding='utf8') as f:
	f.write('export const Liber777 = ')
	json.dump(o, f, ensure_ascii=False)
	f.write(';')
